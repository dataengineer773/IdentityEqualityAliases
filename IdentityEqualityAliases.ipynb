# %%
charles = {'name': 'Charles L. Dodgon', 'born': 1832}

# %%
Lewise = charles

# %%
Lewise is charles
# Out:
# True

# %%
id(charles), id(Lewise)
# Out:
# (1727295941440, 1727295941440)

# %%
Lewise['balance'] = 950

# %%
charles
# Out:
# {'name': 'Charles L. Dodgon', 'born': 1832, 'balance': 950}
